# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
# !pip install geopandas
import geopandas as gpd
# Out:
# ...
#      |████████████████████████████████| 931kB 4.8MB/s
# ...
#      |████████████████████████████████| 10.1MB 26.5MB/s
# ...
#      |████████████████████████████████| 11.8MB 52.4MB/s
# ...

# %% [markdown]
# ##Reading Fire History Shapefile

# %%
#read fire spot
fp = "/content/gdrive/My Drive/wildfire/datasets/fire history/selected_fire.shp"
fire = gpd.read_file(fp)

# %%
fire.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
fire.head()
# Out:
#    OBJECTID  ...                                           geometry
# 0   20326.0  ...  POLYGON ((-122.38889 38.32302, -122.38874 38.3...
# 1   20331.0  ...  POLYGON ((-122.58171 38.46911, -122.58168 38.4...
# 2   20332.0  ...  POLYGON ((-122.62899 38.37824, -122.62888 38.3...
#
# [3 rows x 19 columns]

# %%
out_path = '/content/gdrive/My Drive/wildfire/datasets/fire history/'+out_name
  layer.to_file(out_path)

# %%
fire[fire['FIRE_NAME'] == 'PRESSLEY'].to_file('/content/gdrive/My Drive/wildfire/datasets/fire history/PRESSLEY.shp')

# %%
fire['YEAR_'].dropna(inplace=True)

# %%
fire['YEAR_'] = fire['YEAR_'].astype(int)

# %%
fire.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 19 columns):
# OBJECTID      3 non-null float64
# YEAR_         3 non-null float64
# STATE         3 non-null object
# AGENCY        3 non-null object
# UNIT_ID       3 non-null object
# FIRE_NAME     3 non-null object
# INC_NUM       3 non-null object
# ALARM_DATE    3 non-null object
# CONT_DATE     3 non-null object
# CAUSE         3 non-null float64
# COMMENTS      2 non-null object
# REPORT_AC     3 non-null float64
# GIS_ACRES     3 non-null float64
# C_METHOD      3 non-null float64
# OBJECTIVE     3 non-null float64
# FIRE_NUM      0 non-null object
# Shape_Leng    3 non-null float64
# Shape_Area    3 non-null float64
# geometry      3 non-null geometry
# dtypes: float64(9), geometry(1), object(9)
# memory usage: 584.0+ bytes

# %%
fire.head()
# Out:
#    OBJECTID  ...                                           geometry
# 0       1.0  ...  POLYGON ((-118.49851 34.38242, -118.49797 34.3...
# 1       2.0  ...  POLYGON ((-118.58448 34.41978, -118.58424 34.4...
# 2       3.0  ...  POLYGON ((-118.75645 34.59651, -118.75454 34.5...
# 3       4.0  ...  POLYGON ((-118.07277 34.50198, -118.07271 34.5...
# 4       5.0  ...  POLYGON ((-118.74408 34.08130, -118.74384 34.0...
#
# [5 rows x 19 columns]

# %%
for i in range(0,3):
  fire_name = fire.ix[i, 'FIRE_NAME']
  out_name = 'fire_history_%s'%fire_name
  out_path = '/content/gdrive/My Drive/wildfire/datasets/fire history/'+out_name
  layer.to_file(out_path)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-5fa8c71c5cec> in <module>()
#       3   out_name = 'fire_history_%s'%fire_name
#       4   out_path = '/content/gdrive/My Drive/wildfire/datasets/fire history/'+out_name
# ----> 5   layer.to_file(out_path)
#
# AttributeError: 'tuple' object has no attribute 'to_file'

# %% [markdown]
# ###Filter fire by year

# %%
fire18 = fire[fire['YEAR_'] == 2018]
fire18.head()
# Out:
#        OBJECTID  ...                                           geometry
# 19594   20214.0  ...  POLYGON ((-120.18282 34.71320, -120.18279 34.7...
# 19598   20218.0  ...  MULTIPOLYGON (((-119.80150 34.93862, -119.8015...
# 20096   20716.0  ...  MULTIPOLYGON (((-121.09269 38.25573, -121.0926...
# 20097   20717.0  ...  POLYGON ((-121.17830 38.58453, -121.17834 38.5...
# 20098   20718.0  ...  POLYGON ((-121.03270 38.54476, -121.03274 38.5...
#
# [5 rows x 19 columns]

# %%
for i in range(2013, 2019):
  yearly = fire[fire['YEAR_'] == i]
  out_name = 'fire_history_%d'%i
  out_path = '/content/gdrive/My Drive/wildfire/datasets/fire history/'+out_name
  yearly.to_file(out_path)
