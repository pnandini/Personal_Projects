# %%
# !pip install geopandas
import geopandas as gpd
# Out:
# ...
#      |████████████████████████████████| 931kB 2.7MB/s
# ...
#      |████████████████████████████████| 10.4MB 16.0MB/s
# ...
#      |████████████████████████████████| 14.7MB 312kB/s
# ...

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
fp2 = "/content/gdrive/My Drive/Projects/grid_Feb18_2km.shp"
grid = gpd.read_file(fp2)
grid.head()
# Out:
#         left       top  ...  id                                           geometry
# 0 -122.68004  38.47848  ...   1  POLYGON ((-122.68004 38.47848, -122.67104 38.4...
# 1 -122.68004  38.46948  ...   2  POLYGON ((-122.68004 38.46948, -122.67104 38.4...
# 2 -122.68004  38.46048  ...   3  POLYGON ((-122.68004 38.46048, -122.67104 38.4...
# 3 -122.68004  38.45148  ...   4  POLYGON ((-122.68004 38.45148, -122.67104 38.4...
# 4 -122.68004  38.44248  ...   5  POLYGON ((-122.68004 38.44248, -122.67104 38.4...
#
# [5 rows x 6 columns]

# %%
grid.shape
# Out:
# (1240, 6)

# %%
box = grid.iloc[[-2]]

# %%
box
# Out:
#            left  ...                                           geometry
# 1238 -122.32904  ...  POLYGON ((-122.32904 38.21748, -122.32004 38.2...
#
# [1 rows x 6 columns]

# %%
box.to_file('/content/gdrive/My Drive/Projects/pinpoint_-2.shp')

# %%
#read in the GeoTiff files

# %%
from osgeo import gdal
import sys

# this allows GDAL to throw Python Exceptions
hillshade = gdal.Open("/content/gdrive/My Drive/Projects/sonoma_hillshade.tif")

# %%
hillshade.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-a70fb5b2ecd0> in <module>()
# ----> 1 hillshade.crs()
#
# /usr/lib/python3/dist-packages/osgeo/gdal.py in <lambda>(self, name)
#    1795     for _s in [MajorObject]:
#    1796         __swig_getmethods__.update(getattr(_s, '__swig_getmethods__', {}))
# -> 1797     __getattr__ = lambda self, name: _swig_getattr(self, Dataset, name)
#    1798
#    1799     def __init__(self, *args, **kwargs):
#
# /usr/lib/python3/dist-packages/osgeo/gdal.py in _swig_getattr(self, class_type, name)
#      78     if method:
#      79         return method(self)
# ---> 80     raise AttributeError("'%s' object has no attribute '%s'" % (class_type.__name__, name))
#      81
#      82
#
# AttributeError: 'Dataset' object has no attribute 'crs'
